# %%
# Lightweight path setup for local Jupyter, VS Code, or Colab runs.
# It keeps the notebook runnable whether you start it from this folder or the repo root.
from pathlib import Path
import os

FOLDER_NAME = '06-Neural-Networks-Classification-TensorFlow'
NOTEBOOK_NAME = 'Project_03_NN_Custom Images_Circles_Cross_TFlow.ipynb'

candidates = [
    Path.cwd(),
    Path.cwd() / FOLDER_NAME,
    Path.cwd() / "10-deep_learning" / FOLDER_NAME,
    Path.cwd().parent / FOLDER_NAME,
    Path.cwd().parent / "10-deep_learning" / FOLDER_NAME,
]

for candidate in candidates:
    if (candidate / NOTEBOOK_NAME).exists():
        os.chdir(candidate)
        break

print("Working directory:", Path.cwd().resolve())

# %%
! pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %% [markdown]
# # Import the Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation
from keras.preprocessing.image import ImageDataGenerator
import splitfolders
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')

# %% [markdown]
# # Check the GPU

# %%
print('GPU name: ', tf.config.experimental.list_physical_devices('GPU'))
# Out:
# GPU name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Mount the drive and set the path

# %% [markdown]
# # Split the folder into train and test and Prepare train and test datasets, Loaders

# %%
splitfolders.ratio("Circle_Cross", output="TrainTest",
    seed=1337, ratio=(.8, .2), group_prefix=None, move=False) # default values
# Out:
# Copying files: 2001 files [01:05, 30.41 files/s]

# %% [markdown]
# # Generating Train and Test Data Generators

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
num_classes = 2
img_shape = (116,116,3)
batch_size = 32

# %% [markdown]
# ## Creating Training and Testing Dataset

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Neural Network for classification Tensorflow/TrainTest/train',
                                                 target_size = (116,116),
                                                 class_mode='binary',
                                                 shuffle = True,
                                                 batch_size = batch_size)
# Out:
# Found 1599 images belonging to 2 classes.

# %%
test_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Neural Network for classification Tensorflow/TrainTest/val',
                                                 target_size = (116,116),
                                                 class_mode='binary',
                                                 shuffle = False,
                                                 batch_size = batch_size)
# Out:
# Found 401 images belonging to 2 classes.

# %% [markdown]
# ## Define the model

# %%
model = Sequential()
model.add(Flatten(input_shape = [116,116,3]))  # 116 x 116 x 3 = 40368
model.add(Dense(units = 2048, activation = 'relu'))
model.add(Dense(units = 2048, activation = 'relu'))
model.add(Dense(units = 1024, activation = 'relu'))
model.add(Dense(units = 512, activation = 'relu'))
model.add(Dense(units = 256, activation = 'relu'))
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 40368)             0
#
#  dense (Dense)               (None, 2048)              82675712
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dense_3 (Dense)             (None, 512)               524800
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 89667585 (342.05 MB)
# Trainable params: 89667585 (342.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = 0.001, momentum = 0.9) ,loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Train and Test the model

# %%
hist = model.fit(training_set, epochs = 36, validation_data = test_set)
# Out:
# Epoch 1/36
# 50/50 [==============================] - 10s 137ms/step - loss: 0.6381 - accuracy: 0.6129 - val_loss: 0.6825 - val_accuracy: 0.4988
# Epoch 2/36
# 50/50 [==============================] - 7s 132ms/step - loss: 0.4044 - accuracy: 0.8168 - val_loss: 0.2264 - val_accuracy: 0.9401
# Epoch 3/36
# 50/50 [==============================] - 7s 134ms/step - loss: 0.3417 - accuracy: 0.8487 - val_loss: 0.4169 - val_accuracy: 0.8279
# Epoch 4/36
# 50/50 [==============================] - 6s 126ms/step - loss: 0.2834 - accuracy: 0.8881 - val_loss: 0.5133 - val_accuracy: 0.6334
# Epoch 5/36
# 50/50 [==============================] - 7s 145ms/step - loss: 0.3161 - accuracy: 0.8649 - val_loss: 0.5401 - val_accuracy: 0.6185
# Epoch 6/36
# 50/50 [==============================] - 6s 125ms/step - loss: 0.3393 - accuracy: 0.8593 - val_loss: 0.3853 - val_accuracy: 0.7880
# Epoch 7/36
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1698 - accuracy: 0.9381 - val_loss: 0.0842 - val_accuracy: 0.9676
# Epoch 8/36
# 50/50 [==============================] - 7s 131ms/step - loss: 0.1023 - accuracy: 0.9587 - val_loss: 0.0676 - val_accuracy: 0.9751
# Epoch 9/36
# 50/50 [==============================] - 8s 152ms/step - loss: 0.1867 - accuracy: 0.9231 - val_loss: 0.1505 - val_accuracy: 0.9476
# Epoch 10/36
# 50/50 [==============================] - 8s 157ms/step - loss: 0.1021 - accuracy: 0.9656 - val_loss: 0.0646 - val_accuracy: 0.9726
# Epoch 11/36
# 50/50 [==============================] - 7s 133ms/step - loss: 0.0869 - accuracy: 0.9650 - val_loss: 0.0609 - val_accuracy: 0.9751
# Epoch 12/36
# 50/50 [==============================] - 7s 135ms/step - loss: 0.0442 - accuracy: 0.9844 - val_loss: 0.0702 - val_accuracy: 0.9676
# Epoch 13/36
# 50/50 [==============================] - 7s 133ms/step - loss: 0.0844 - accuracy: 0.9662 - val_loss: 0.0733 - val_accuracy: 0.9601
# Epoch 14/36
# 50/50 [==============================] - 7s 131ms/step - loss: 0.0449 - accuracy: 0.9819 - val_loss: 0.0745 - val_accuracy: 0.9751
# Epoch 15/36
# 50/50 [==============================] - 7s 136ms/step - loss: 0.1302 - accuracy: 0.9531 - val_loss: 0.0508 - val_accuracy: 0.9800
# Epoch 16/36
# 50/50 [==============================] - 7s 133ms/step - loss: 0.0584 - accuracy: 0.9762 - val_loss: 0.0705 - val_accuracy: 0.9800
# Epoch 17/36
# 50/50 [==============================] - 7s 142ms/step - loss: 0.0257 - accuracy: 0.9925 - val_loss: 0.0495 - val_accuracy: 0.9800
# Epoch 18/36
# 50/50 [==============================] - 6s 129ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.0791 - val_accuracy: 0.9751
# Epoch 19/36
# 50/50 [==============================] - 6s 127ms/step - loss: 0.1976 - accuracy: 0.9362 - val_loss: 0.0668 - val_accuracy: 0.9825
# Epoch 20/36
# 50/50 [==============================] - 7s 144ms/step - loss: 0.0524 - accuracy: 0.9850 - val_loss: 0.0612 - val_accuracy: 0.9800
# Epoch 21/36
# 50/50 [==============================] - 7s 145ms/step - loss: 0.1428 - accuracy: 0.9425 - val_loss: 0.0594 - val_accuracy: 0.9800
# Epoch 22/36
# 50/50 [==============================] - 7s 144ms/step - loss: 0.0652 - accuracy: 0.9775 - val_loss: 0.0679 - val_accuracy: 0.9651
# Epoch 23/36
# 50/50 [==============================] - 6s 126ms/step - loss: 0.0740 - accuracy: 0.9794 - val_loss: 1.4421 - val_accuracy: 0.6908
# Epoch 24/36
# 50/50 [==============================] - 7s 149ms/step - loss: 0.2627 - accuracy: 0.8981 - val_loss: 0.2531 - val_accuracy: 0.8878
# Epoch 25/36
# 50/50 [==============================] - 7s 131ms/step - loss: 0.0842 - accuracy: 0.9625 - val_loss: 0.0543 - val_accuracy: 0.9800
# Epoch 26/36
# 50/50 [==============================] - 7s 143ms/step - loss: 0.0501 - accuracy: 0.9806 - val_loss: 0.0449 - val_accuracy: 0.9825
# Epoch 27/36
# 50/50 [==============================] - 6s 126ms/step - loss: 0.0580 - accuracy: 0.9775 - val_loss: 0.0743 - val_accuracy: 0.9676
# Epoch 28/36
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0925 - accuracy: 0.9619 - val_loss: 0.0627 - val_accuracy: 0.9726
# Epoch 29/36
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0628 - accuracy: 0.9794 - val_loss: 0.0836 - val_accuracy: 0.9751
# Epoch 30/36
# 50/50 [==============================] - 7s 143ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0388 - val_accuracy: 0.9825
# Epoch 31/36
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0205 - accuracy: 0.9944 - val_loss: 0.0464 - val_accuracy: 0.9850
# Epoch 32/36
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0625 - val_accuracy: 0.9776
# Epoch 33/36
# 50/50 [==============================] - 6s 124ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.0452 - val_accuracy: 0.9850
# Epoch 34/36
# 50/50 [==============================] - 7s 144ms/step - loss: 0.0230 - accuracy: 0.9919 - val_loss: 0.0655 - val_accuracy: 0.9800
# Epoch 35/36
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0335 - accuracy: 0.9875 - val_loss: 0.7208 - val_accuracy: 0.8130
# Epoch 36/36
# 50/50 [==============================] - 7s 137ms/step - loss: 0.1757 - accuracy: 0.9362 - val_loss: 0.0482 - val_accuracy: 0.9825

# %%
trainAcc = [100 * x for x in hist.history['accuracy']]
testAcc = [100 * x for x in hist.history['val_accuracy']]

# %% [markdown]
# # Visualize the performance of model

# %%
fig,ax = plt.subplots(1,2,figsize=(18,6))

ax[0].plot(hist.history['loss'], 'g', lw = 3, label = 'Train')
ax[0].set_xlabel('Epochs', fontsize = 15)
ax[0].set_ylabel('Loss', fontsize = 15)
ax[0].legend(fontsize = 15)
ax[0].set_title('Training Loss', fontsize = 15)


ax[1].plot(trainAcc, label ='Train', lw = 3)
ax[1].plot(testAcc, label ='Test', lw = 3)
ax[1].set_xlabel('Epochs', fontsize = 15)
ax[1].set_ylabel('Accuracy (%)', fontsize = 15)
ax[1].set_ylim([10,110])
ax[1].set_title(f'Train Accuracy: {trainAcc[-1]:.2f}% \n Test Accuracy: {testAcc[-1]:.2f}%', fontsize = 15)
ax[1].legend(fontsize = 15)

plt.show()
